# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("Import Successfully")
# Out:
# Import Successfully

# %% [markdown]
# ### Working with Images

# %%
import matplotlib.image as mpimg

# %%
a=np.linspace(1,5,10)
b=a**2
b
# Out:
# array([ 1.        ,  2.08641975,  3.56790123,  5.44444444,  7.71604938,
#        10.38271605, 13.44444444, 16.90123457, 20.75308642, 25.        ])

# %%
img=mpimg.imread('../Images/Viratimage.jpg')
plt.imshow(img)
plt.show()

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
crop_img=img[40:200,50:300]
plt.imshow(crop_img)
plt.show()
# print(img.shape)

# %% [markdown]
# ### Optional Designing

# %%
plt.plot(a,b,color='red')

# %%
plt.plot(a,b,color='red',marker='o',linestyle='dotted')

# %%
xaxis = np.linspace(0,5,11)
